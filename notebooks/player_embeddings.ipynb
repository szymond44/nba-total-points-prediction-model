# %% [markdown]
# # 🏀 NBA Team Points Prediction Model
# ## 📈 Embedding Model Testing
#
# 🙋 authors: szymond44, gwiazdan
# 📆 date: 21-07-2025

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..','src')))

# %% [markdown]
# ### ✏️ Introduction
# Predicting NBA team points is a challenging problem. One promising approach is to represent each player with a learned embedding that is updated after every game to reflect current form and reduce reliance on long-term history. This framing raises several key design questions:
# - Which features should the embedding encode?
# - Should embeddings be derived from single games, or from sequences of recent games to capture temporal dynamics?
# - How should we balance recency with historical information and regularize updates over time?
#
# In this notebook, we compare alternative constructions—single-game versus sequence-based player embeddings—and evaluate which most accurately captures recent form for downstream team-points prediction.

# %% [markdown]
# ### Preparatory work

# %%
from api_fetcher import ApiFetcher
