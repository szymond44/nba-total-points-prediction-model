# %%
import sys
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
# %load_ext autoreload
# %autoreload 2
from data.api_fetcher import ApiFetcher
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
api = ApiFetcher(starting_year=2014, ending_year=2025)
df = api.get_dataframe(numeric=False, date=True, time_coeff=False, ids=True)

# %%
df1 = df.copy()
cols_to_drop = [col for col in ['home_team', 'away_team'] if col in df1.columns]
df1.drop(cols_to_drop, axis=1, inplace=True)

# %%
    import pandas as pd
    import numpy as np
    from sklearn.preprocessing import StandardScaler

    def prep_df(df1, target_cols=['home_pts', 'away_pts']):
        team_id_cols = ['home_team_id', 'away_team_id']
        exclude_cols = target_cols + team_id_cols + ['date', 'home_team', 'away_team']
        numeric_cols = [col for col in df1.columns if col not in exclude_cols]


        X_numeric_raw = df1[numeric_cols].values
        X_team_ids = df1[team_id_cols].astype(int).values
        y = df1[target_cols].values 

        scaler = StandardScaler()
        X_numeric = scaler.fit_transform(X_numeric_raw)

        return X_numeric, X_team_ids, y, scaler, numeric_cols
    X_numeric, X_team_ids, y, scaler, numeric_cols = prep_df(df)
    print("X_numeric shape:", X_numeric.shape)
    print("X_team_ids shape:", X_team_ids.shape)
    print("y shape:", y.shape)
# Out:
# X_numeric shape: (13203, 22)
# X_team_ids shape: (13203, 2)
# y shape: (13203, 2)

# %%
X_numeric, X_team_ids, y, scaler, numeric_cols = prep_df(df1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TeamEmbeddingNN(nn.Module):
    def __init__(self, num_teams, embedding_dim, num_numeric_features):
        super(TeamEmbeddingNN, self).__init__()
        
        # Embedding layers for home and away teams
        self.home_embedding = nn.Embedding(num_teams, embedding_dim)
        self.away_embedding = nn.Embedding(num_teams, embedding_dim)
        
        # Input layer size = numeric features + 2 embeddings concatenated
        input_size = num_numeric_features + embedding_dim * 2
        
        # Hidden layers
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        
        # Output layer (predict home_pts and away_pts)
        self.out = nn.Linear(32, 2)
        
    def forward(self, numeric_features, team_ids):
        
        home_emb = self.home_embedding(team_ids[:, 0])
        away_emb = self.away_embedding(team_ids[:, 1])
        
        # Concatenate embeddings with numeric features
        x = torch.cat([numeric_features, home_emb, away_emb], dim=1)
        
        # Forward pass through hidden layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        
        # Output predicted points
        out = self.out(x)
        return out

# %%
#TEST - NIEISTOTNE NARAZIE 

import torch
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Chronological split ---
df_sorted = df1.sort_values('date')
n = len(df_sorted)
train_end = int(0.7 * n)
val_end = int(0.85 * n)

train_df = df_sorted.iloc[:train_end]
val_df = df_sorted.iloc[train_end:val_end]
test_df = df_sorted.iloc[val_end:]

# --- 2. Preprocess splits ---
X_train_num, X_train_ids, y_train, scaler, numeric_cols = prep_df(train_df)
X_val_num, X_val_ids, y_val, _, _ = prep_df(val_df)
X_test_num, X_test_ids, y_test, _, _ = prep_df(test_df)

# --- 3. Dataset class ---
class NBAEmbeddingDataset(Dataset):
    def __init__(self, X_numeric, X_team_ids, y):
        self.X_numeric = torch.tensor(X_numeric, dtype=torch.float32)
        self.X_team_ids = torch.tensor(X_team_ids, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X_numeric[idx], self.X_team_ids[idx], self.y[idx]

train_dataset = NBAEmbeddingDataset(X_train_num, X_train_ids, y_train)
val_dataset = NBAEmbeddingDataset(X_val_num, X_val_ids, y_val)
test_dataset = NBAEmbeddingDataset(X_test_num, X_test_ids, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# --- 4. Instantiate model ---
num_teams = df1['home_team_id'].nunique()
embedding_dim = 8
num_numeric_features = X_train_num.shape[1]

model = TeamEmbeddingNN(num_teams, embedding_dim, num_numeric_features)

# --- 5. Loss and optimizer ---
criterion = torch.nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# --- 6. OneCycleLR ---
steps_per_epoch = len(train_loader)
num_epochs = 100  # can be any number
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=0.01,
    steps_per_epoch=steps_per_epoch,
    epochs=num_epochs
)

# --- 7. Training loop with early stopping & LR tracking ---
patience = 100
min_delta = 1e-4

train_losses = []
val_losses = []
lrs = []  # track learning rate

best_val_loss = np.inf
epochs_no_improve = 0
best_model_state = None

for epoch in range(num_epochs):
    model.train()
    train_loss_epoch = 0
    for X_num_batch, X_ids_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_num_batch, X_ids_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Track LR
        current_lr = optimizer.param_groups[0]['lr']
        lrs.append(current_lr)
        
        train_loss_epoch += loss.item() * X_num_batch.size(0)
    train_loss_epoch /= len(train_loader.dataset)
    train_losses.append(train_loss_epoch)
    
    # Validation
    model.eval()
    val_loss_epoch = 0
    with torch.no_grad():
        for X_num_batch, X_ids_batch, y_batch in val_loader:
            outputs = model(X_num_batch, X_ids_batch)
            loss = criterion(outputs, y_batch)
            val_loss_epoch += loss.item() * X_num_batch.size(0)
    val_loss_epoch /= len(val_loader.dataset)
    val_losses.append(val_loss_epoch)
    
    print(f"Epoch {epoch+1:03d} | Train MSE: {train_loss_epoch:.4f} | Val MSE: {val_loss_epoch:.4f} | LR: {current_lr:.6f}")
    
    # Early stopping
    if val_loss_epoch + min_delta < best_val_loss:
        best_val_loss = val_loss_epoch
        epochs_no_improve = 0
        best_model_state = model.state_dict()
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

# --- Load best model ---
if best_model_state is not None:
    model.load_state_dict(best_model_state)

# --- 8. Plot MSE per actual epoch ---
plt.figure(figsize=(10,6))
plt.plot(range(1, len(train_losses)+1), train_losses, label='Train MSE')
plt.plot(range(1, len(val_losses)+1), val_losses, label='Validation MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('Train and Validation MSE per Epoch')
plt.legend()
plt.show()

# --- 9. Plot Learning Rate schedule ---
plt.figure(figsize=(10,5))
plt.plot(lrs)
plt.xlabel('Batch step')
plt.ylabel('Learning rate')
plt.title('Learning Rate Schedule (OneCycleLR)')
plt.show()

# --- 10. Evaluate on test set ---
model.eval()
test_loss = 0
with torch.no_grad():
    for X_num_batch, X_ids_batch, y_batch in test_loader:
        outputs = model(X_num_batch, X_ids_batch)
        loss = criterion(outputs, y_batch)
        test_loss += loss.item() * X_num_batch.size(0)
test_loss /= len(test_loader.dataset)
print(f"Test MSE: {test_loss:.4f}")

# --- 11. Extract embeddings ---
home_vectors = model.home_embedding.weight.data.cpu().numpy()
away_vectors = model.away_embedding.weight.data.cpu().numpy()
# Out:
# Epoch 001 | Train MSE: 11355.8865 | Val MSE: 12296.4859 | LR: 0.000426
# Epoch 002 | Train MSE: 8027.3746 | Val MSE: 4782.5626 | LR: 0.000505
# Epoch 003 | Train MSE: 1594.4436 | Val MSE: 1002.6659 | LR: 0.000635
# Epoch 004 | Train MSE: 572.2272 | Val MSE: 570.7740 | LR: 0.000815
# Epoch 005 | Train MSE: 342.2829 | Val MSE: 376.0422 | LR: 0.001043
# Epoch 006 | Train MSE: 213.6132 | Val MSE: 257.1485 | LR: 0.001317
# Epoch 007 | Train MSE: 133.8230 | Val MSE: 179.5456 | LR: 0.001633
# Epoch 008 | Train MSE: 82.1014 | Val MSE: 126.6241 | LR: 0.001989
# Epoch 009 | Train MSE: 51.8893 | Val MSE: 102.7289 | LR: 0.002379
# Epoch 010 | Train MSE: 36.4897 | Val MSE: 98.1486 | LR: 0.002801
# Epoch 011 | Train MSE: 27.7819 | Val MSE: 89.0582 | LR: 0.003249
# Epoch 012 | Train MSE: 22.7269 | Val MSE: 82.6513 | LR: 0.003718
# Epoch 013 | Train MSE: 19.9872 | Val MSE: 76.2563 | LR: 0.004203
# Epoch 014 | Train MSE: 18.6581 | Val MSE: 83.0539 | LR: 0.004700
# Epoch 015 | Train MSE: 17.5066 | Val MSE: 66.3737 | LR: 0.005202
# Epoch 016 | Train MSE: 16.7532 | Val MSE: 74.3257 | LR: 0.005704
# Epoch 017 | Train MSE: 16.5872 | Val MSE: 75.6884 | LR: 0.006200
# Epoch 018 | Train MSE: 16.1564 | Val MSE: 64.7325 | LR: 0.006685
# Epoch 019 | Train MSE: 15.6105 | Val MSE: 66.6798 | LR: 0.007154
# Epoch 020 | Train MSE: 15.6902 | Val MSE: 85.3548 | LR: 0.007602
# Epoch 021 | Train MSE: 15.8343 | Val MSE: 79.1015 | LR: 0.008023
# Epoch 022 | Train MSE: 15.3570 | Val MSE: 74.9689 | LR: 0.008414
# Epoch 023 | Train MSE: 15.2828 | Val MSE: 62.6590 | LR: 0.008769
# Epoch 024 | Train MSE: 15.3517 | Val MSE: 78.2068 | LR: 0.009085
# Epoch 025 | Train MSE: 16.6975 | Val MSE: 68.8840 | LR: 0.009358
# Epoch 026 | Train MSE: 15.0989 | Val MSE: 80.2901 | LR: 0.009586
# Epoch 027 | Train MSE: 15.6139 | Val MSE: 76.1737 | LR: 0.009766
# Epoch 028 | Train MSE: 15.9267 | Val MSE: 98.4815 | LR: 0.009896
# Epoch 029 | Train MSE: 15.7674 | Val MSE: 56.9525 | LR: 0.009974
# Epoch 030 | Train MSE: 16.1527 | Val MSE: 70.1073 | LR: 0.010000
# Epoch 031 | Train MSE: 16.0061 | Val MSE: 58.0109 | LR: 0.009995
# Epoch 032 | Train MSE: 15.9356 | Val MSE: 57.9818 | LR: 0.009980
# Epoch 033 | Train MSE: 15.4070 | Val MSE: 83.8886 | LR: 0.009955
# Epoch 034 | Train MSE: 15.5540 | Val MSE: 80.3616 | LR: 0.009919
# Epoch 035 | Train MSE: 16.3142 | Val MSE: 77.6222 | LR: 0.009874
# Epoch 036 | Train MSE: 15.5235 | Val MSE: 81.6361 | LR: 0.009819
# Epoch 037 | Train MSE: 15.1119 | Val MSE: 67.0932 | LR: 0.009755
# Epoch 038 | Train MSE: 15.1408 | Val MSE: 60.7510 | LR: 0.009681
# Epoch 039 | Train MSE: 15.6265 | Val MSE: 110.0931 | LR: 0.009597
# Epoch 040 | Train MSE: 15.2813 | Val MSE: 91.8758 | LR: 0.009504
# Epoch 041 | Train MSE: 14.3650 | Val MSE: 75.1171 | LR: 0.009402
# Epoch 042 | Train MSE: 14.9344 | Val MSE: 70.8188 | LR: 0.009291
# Epoch 043 | Train MSE: 14.9468 | Val MSE: 50.8637 | LR: 0.009172
# Epoch 044 | Train MSE: 15.0898 | Val MSE: 139.0560 | LR: 0.009044
# Epoch 045 | Train MSE: 15.2698 | Val MSE: 69.7352 | LR: 0.008908
# Epoch 046 | Train MSE: 14.3436 | Val MSE: 53.9829 | LR: 0.008764
# Epoch 047 | Train MSE: 14.3065 | Val MSE: 101.6862 | LR: 0.008613
# Epoch 048 | Train MSE: 13.9640 | Val MSE: 55.5013 | LR: 0.008454
# Epoch 049 | Train MSE: 14.4531 | Val MSE: 82.5936 | LR: 0.008289
# Epoch 050 | Train MSE: 14.8654 | Val MSE: 103.1244 | LR: 0.008116
# Epoch 051 | Train MSE: 14.3398 | Val MSE: 54.9192 | LR: 0.007938
# Epoch 052 | Train MSE: 13.7590 | Val MSE: 64.2679 | LR: 0.007753
# Epoch 053 | Train MSE: 13.5061 | Val MSE: 99.3246 | LR: 0.007563
# Epoch 054 | Train MSE: 12.9370 | Val MSE: 65.3264 | LR: 0.007368
# Epoch 055 | Train MSE: 12.7424 | Val MSE: 66.0737 | LR: 0.007168
# Epoch 056 | Train MSE: 13.1445 | Val MSE: 69.5330 | LR: 0.006964
# Epoch 057 | Train MSE: 13.4628 | Val MSE: 77.2325 | LR: 0.006755
# Epoch 058 | Train MSE: 13.5967 | Val MSE: 59.8413 | LR: 0.006544
# Epoch 059 | Train MSE: 12.5657 | Val MSE: 83.1634 | LR: 0.006329
# Epoch 060 | Train MSE: 12.7729 | Val MSE: 63.8656 | LR: 0.006111
# Epoch 061 | Train MSE: 12.3571 | Val MSE: 85.7478 | LR: 0.005891
# Epoch 062 | Train MSE: 12.2424 | Val MSE: 70.4357 | LR: 0.005670
# Epoch 063 | Train MSE: 12.2987 | Val MSE: 73.7731 | LR: 0.005447
# Epoch 064 | Train MSE: 12.1215 | Val MSE: 71.5784 | LR: 0.005223
# Epoch 065 | Train MSE: 12.0821 | Val MSE: 66.9711 | LR: 0.004998
# Epoch 066 | Train MSE: 11.9503 | Val MSE: 73.6515 | LR: 0.004774
# Epoch 067 | Train MSE: 11.9037 | Val MSE: 55.0696 | LR: 0.004550
# Epoch 068 | Train MSE: 11.9569 | Val MSE: 73.4280 | LR: 0.004327
# Epoch 069 | Train MSE: 11.8647 | Val MSE: 73.5995 | LR: 0.004106
# Epoch 070 | Train MSE: 11.5675 | Val MSE: 65.2300 | LR: 0.003886
# Epoch 071 | Train MSE: 11.3107 | Val MSE: 61.7316 | LR: 0.003668
# Epoch 072 | Train MSE: 11.4500 | Val MSE: 84.4475 | LR: 0.003453
# Epoch 073 | Train MSE: 11.5312 | Val MSE: 98.2665 | LR: 0.003242
# Epoch 074 | Train MSE: 11.1526 | Val MSE: 71.4915 | LR: 0.003033
# Epoch 075 | Train MSE: 10.9330 | Val MSE: 75.1874 | LR: 0.002829
# Epoch 076 | Train MSE: 10.8159 | Val MSE: 67.2818 | LR: 0.002629
# Epoch 077 | Train MSE: 11.1927 | Val MSE: 87.8062 | LR: 0.002434
# Epoch 078 | Train MSE: 10.6923 | Val MSE: 73.5873 | LR: 0.002244
# Epoch 079 | Train MSE: 10.5251 | Val MSE: 73.0273 | LR: 0.002060
# Epoch 080 | Train MSE: 10.5189 | Val MSE: 77.1559 | LR: 0.001881
# Epoch 081 | Train MSE: 10.3894 | Val MSE: 80.2972 | LR: 0.001709
# Epoch 082 | Train MSE: 10.2086 | Val MSE: 72.4074 | LR: 0.001544
# Epoch 083 | Train MSE: 10.3811 | Val MSE: 69.2279 | LR: 0.001385
# Epoch 084 | Train MSE: 10.2027 | Val MSE: 75.1764 | LR: 0.001234
# Epoch 085 | Train MSE: 10.1069 | Val MSE: 72.8779 | LR: 0.001090
# Epoch 086 | Train MSE: 10.3023 | Val MSE: 59.2396 | LR: 0.000954
# Epoch 087 | Train MSE: 10.0111 | Val MSE: 70.9557 | LR: 0.000826
# Epoch 088 | Train MSE: 9.8844 | Val MSE: 77.0524 | LR: 0.000707
# Epoch 089 | Train MSE: 9.9115 | Val MSE: 66.9981 | LR: 0.000596
# Epoch 090 | Train MSE: 9.8413 | Val MSE: 72.0985 | LR: 0.000495
# Epoch 091 | Train MSE: 9.7616 | Val MSE: 77.0229 | LR: 0.000402
# Epoch 092 | Train MSE: 9.7466 | Val MSE: 78.9645 | LR: 0.000318
# Epoch 093 | Train MSE: 9.6906 | Val MSE: 71.7833 | LR: 0.000244
# Epoch 094 | Train MSE: 9.7020 | Val MSE: 74.2755 | LR: 0.000180
# Epoch 095 | Train MSE: 9.6511 | Val MSE: 71.2124 | LR: 0.000125
# Epoch 096 | Train MSE: 9.5981 | Val MSE: 71.4152 | LR: 0.000080
# Epoch 097 | Train MSE: 9.5860 | Val MSE: 69.6682 | LR: 0.000045
# Epoch 098 | Train MSE: 9.5542 | Val MSE: 71.5148 | LR: 0.000020
# Epoch 099 | Train MSE: 9.5398 | Val MSE: 71.8159 | LR: 0.000005
# Epoch 100 | Train MSE: 9.5323 | Val MSE: 71.6803 | LR: 0.000000
# Test MSE: 57.2661

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Chronological split ---
df_sorted = df1.sort_values('date')
n = len(df_sorted)
train_end = int(0.7 * n)
val_end = int(0.85 * n)

train_df = df_sorted.iloc[:train_end]
val_df = df_sorted.iloc[train_end:val_end]
test_df = df_sorted.iloc[val_end:]

# --- 2. Preprocess splits ---
X_train_num, X_train_ids, y_train, scaler, numeric_cols = prep_df(train_df)
X_val_num, X_val_ids, y_val, _, _ = prep_df(val_df)
X_test_num, X_test_ids, y_test, _, _ = prep_df(test_df)

# --- 3. Dataset class ---
class NBAEmbeddingDataset(Dataset):
    def __init__(self, X_numeric, X_team_ids, y):
        self.X_numeric = torch.tensor(X_numeric, dtype=torch.float32)
        self.X_team_ids = torch.tensor(X_team_ids, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float32)
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X_numeric[idx], self.X_team_ids[idx], self.y[idx]

train_dataset = NBAEmbeddingDataset(X_train_num, X_train_ids, y_train)
val_dataset = NBAEmbeddingDataset(X_val_num, X_val_ids, y_val)
test_dataset = NBAEmbeddingDataset(X_test_num, X_test_ids, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# --- 4. Instantiate model ---
num_teams = df1['home_team_id'].nunique()
embedding_dim = 8
num_numeric_features = X_train_num.shape[1]

model = TeamEmbeddingNN(num_teams, embedding_dim, num_numeric_features)

# --- 5. Loss and optimizer ---
criterion = nn.MSELoss()
learning_rate = 0.009187
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# --- 6. Training loop (fixed epochs) ---
num_epochs = 250

train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # Training
    model.train()
    train_loss_epoch = 0
    for X_num_batch, X_ids_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_num_batch, X_ids_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        train_loss_epoch += loss.item() * X_num_batch.size(0)
    train_loss_epoch /= len(train_loader.dataset)
    train_losses.append(train_loss_epoch)

    # Validation
    model.eval()
    val_loss_epoch = 0
    with torch.no_grad():
        for X_num_batch, X_ids_batch, y_batch in val_loader:
            outputs = model(X_num_batch, X_ids_batch)
            loss = criterion(outputs, y_batch)
            val_loss_epoch += loss.item() * X_num_batch.size(0)
    val_loss_epoch /= len(val_loader.dataset)
    val_losses.append(val_loss_epoch)

    print(f"Epoch {epoch+1}/{num_epochs} | Train MSE: {train_loss_epoch:.4f} | Val MSE: {val_loss_epoch:.4f}")

# --- 7. Plot MSE ---
plt.figure(figsize=(10,6))
plt.plot(range(1, len(train_losses)+1), train_losses, label='Train MSE')
plt.plot(range(1, len(val_losses)+1), val_losses, label='Validation MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('Train and Validation MSE per Epoch')
plt.legend()
plt.show()

# --- 8. Evaluate on test set ---
model.eval()
test_loss = 0
with torch.no_grad():
    for X_num_batch, X_ids_batch, y_batch in test_loader:
        outputs = model(X_num_batch, X_ids_batch)
        loss = criterion(outputs, y_batch)
        test_loss += loss.item() * X_num_batch.size(0)
test_loss /= len(test_loader.dataset)
print(f"Test MSE: {test_loss:.4f}")

# --- 9. Extract embeddings ---
home_vectors = model.home_embedding.weight.data.cpu().numpy()
away_vectors = model.away_embedding.weight.data.cpu().numpy()
# Out:
# Epoch 1/250 | Train MSE: 1752.7888 | Val MSE: 183.1412
# Epoch 2/250 | Train MSE: 62.0947 | Val MSE: 104.9688
# Epoch 3/250 | Train MSE: 26.3272 | Val MSE: 77.3303
# Epoch 4/250 | Train MSE: 18.8468 | Val MSE: 70.3591
# Epoch 5/250 | Train MSE: 16.8049 | Val MSE: 77.8436
# Epoch 6/250 | Train MSE: 16.0225 | Val MSE: 70.2036
# Epoch 7/250 | Train MSE: 15.5087 | Val MSE: 72.1405
# Epoch 8/250 | Train MSE: 15.4092 | Val MSE: 58.7549
# Epoch 9/250 | Train MSE: 15.0682 | Val MSE: 79.5961
# Epoch 10/250 | Train MSE: 15.3424 | Val MSE: 66.8765
# Epoch 11/250 | Train MSE: 14.5396 | Val MSE: 82.3148
# Epoch 12/250 | Train MSE: 15.6475 | Val MSE: 60.6217
# Epoch 13/250 | Train MSE: 15.1461 | Val MSE: 85.6100
# Epoch 14/250 | Train MSE: 14.7901 | Val MSE: 84.0041
# Epoch 15/250 | Train MSE: 15.1452 | Val MSE: 93.4916
# Epoch 16/250 | Train MSE: 14.9824 | Val MSE: 57.5532
# Epoch 17/250 | Train MSE: 16.5621 | Val MSE: 65.6158
# Epoch 18/250 | Train MSE: 15.3723 | Val MSE: 84.0878
# Epoch 19/250 | Train MSE: 14.6158 | Val MSE: 66.5170
# Epoch 20/250 | Train MSE: 14.8009 | Val MSE: 64.2951
# Epoch 21/250 | Train MSE: 14.8015 | Val MSE: 55.4717
# Epoch 22/250 | Train MSE: 15.4795 | Val MSE: 73.8878
# Epoch 23/250 | Train MSE: 14.1769 | Val MSE: 66.7483
# Epoch 24/250 | Train MSE: 15.2271 | Val MSE: 81.2273
# Epoch 25/250 | Train MSE: 15.4261 | Val MSE: 76.5365
# Epoch 26/250 | Train MSE: 15.4195 | Val MSE: 66.7238
# Epoch 27/250 | Train MSE: 15.7405 | Val MSE: 73.7516
# Epoch 28/250 | Train MSE: 14.9544 | Val MSE: 75.9111
# Epoch 29/250 | Train MSE: 14.9191 | Val MSE: 69.5020
# Epoch 30/250 | Train MSE: 14.6910 | Val MSE: 97.7209
# Epoch 31/250 | Train MSE: 14.5466 | Val MSE: 86.9971
# Epoch 32/250 | Train MSE: 14.0754 | Val MSE: 53.7788
# Epoch 33/250 | Train MSE: 15.4001 | Val MSE: 60.7327
# Epoch 34/250 | Train MSE: 15.5217 | Val MSE: 88.8397
# Epoch 35/250 | Train MSE: 14.4180 | Val MSE: 104.3017
# Epoch 36/250 | Train MSE: 15.0084 | Val MSE: 60.7365
# Epoch 37/250 | Train MSE: 15.6936 | Val MSE: 94.3589
# Epoch 38/250 | Train MSE: 15.7819 | Val MSE: 77.4493
# Epoch 39/250 | Train MSE: 14.9737 | Val MSE: 102.9578
# Epoch 40/250 | Train MSE: 15.3477 | Val MSE: 59.8877
# Epoch 41/250 | Train MSE: 14.8265 | Val MSE: 55.3630
# Epoch 42/250 | Train MSE: 14.1039 | Val MSE: 74.7929
# Epoch 43/250 | Train MSE: 13.8596 | Val MSE: 73.6883
# Epoch 44/250 | Train MSE: 13.8997 | Val MSE: 58.2415
# Epoch 45/250 | Train MSE: 14.4297 | Val MSE: 73.5516
# Epoch 46/250 | Train MSE: 14.1219 | Val MSE: 85.0239
# Epoch 47/250 | Train MSE: 14.7179 | Val MSE: 91.0462
# Epoch 48/250 | Train MSE: 14.6143 | Val MSE: 113.8189
# Epoch 49/250 | Train MSE: 14.4205 | Val MSE: 60.1080
# Epoch 50/250 | Train MSE: 14.0940 | Val MSE: 90.9163
# Epoch 51/250 | Train MSE: 13.3196 | Val MSE: 63.2178
# Epoch 52/250 | Train MSE: 13.0777 | Val MSE: 73.9642
# Epoch 53/250 | Train MSE: 13.0149 | Val MSE: 92.6573
# Epoch 54/250 | Train MSE: 14.2459 | Val MSE: 68.0094
# Epoch 55/250 | Train MSE: 14.2774 | Val MSE: 72.4831
# Epoch 56/250 | Train MSE: 13.2361 | Val MSE: 59.6505
# Epoch 57/250 | Train MSE: 13.6687 | Val MSE: 102.4139
# Epoch 58/250 | Train MSE: 13.9514 | Val MSE: 82.2855
# Epoch 59/250 | Train MSE: 13.8046 | Val MSE: 80.1251
# Epoch 60/250 | Train MSE: 13.3092 | Val MSE: 85.4882
# Epoch 61/250 | Train MSE: 13.8514 | Val MSE: 82.7034
# Epoch 62/250 | Train MSE: 14.3910 | Val MSE: 71.7862
# Epoch 63/250 | Train MSE: 12.9192 | Val MSE: 88.2113
# Epoch 64/250 | Train MSE: 13.0575 | Val MSE: 88.4095
# Epoch 65/250 | Train MSE: 13.0547 | Val MSE: 58.5059
# Epoch 66/250 | Train MSE: 13.2602 | Val MSE: 42.1126
# Epoch 67/250 | Train MSE: 13.0579 | Val MSE: 90.7892
# Epoch 68/250 | Train MSE: 13.0120 | Val MSE: 68.0851
# Epoch 69/250 | Train MSE: 12.9961 | Val MSE: 93.2414
# Epoch 70/250 | Train MSE: 12.9953 | Val MSE: 53.7386
# Epoch 71/250 | Train MSE: 14.6886 | Val MSE: 78.3476
# Epoch 72/250 | Train MSE: 13.0215 | Val MSE: 71.3493
# Epoch 73/250 | Train MSE: 13.2750 | Val MSE: 59.9069
# Epoch 74/250 | Train MSE: 13.1657 | Val MSE: 88.2104
# Epoch 75/250 | Train MSE: 13.0581 | Val MSE: 87.4440
# Epoch 76/250 | Train MSE: 12.9672 | Val MSE: 66.0434
# Epoch 77/250 | Train MSE: 13.2851 | Val MSE: 100.6397
# Epoch 78/250 | Train MSE: 12.5867 | Val MSE: 54.4895
# Epoch 79/250 | Train MSE: 13.0235 | Val MSE: 62.6906
# Epoch 80/250 | Train MSE: 13.1722 | Val MSE: 58.7687
# Epoch 81/250 | Train MSE: 12.8605 | Val MSE: 88.4024
# Epoch 82/250 | Train MSE: 12.5589 | Val MSE: 57.7036
# Epoch 83/250 | Train MSE: 12.9846 | Val MSE: 80.9209
# Epoch 84/250 | Train MSE: 12.5673 | Val MSE: 49.8344
# Epoch 85/250 | Train MSE: 13.1173 | Val MSE: 47.1880
# Epoch 86/250 | Train MSE: 12.6163 | Val MSE: 61.4076
# Epoch 87/250 | Train MSE: 12.5234 | Val MSE: 72.7109
# Epoch 88/250 | Train MSE: 13.2222 | Val MSE: 62.8723
# Epoch 89/250 | Train MSE: 13.4929 | Val MSE: 58.0407
# Epoch 90/250 | Train MSE: 12.3699 | Val MSE: 76.9465
# Epoch 91/250 | Train MSE: 12.3306 | Val MSE: 42.2652
# Epoch 92/250 | Train MSE: 13.3334 | Val MSE: 130.8005
# Epoch 93/250 | Train MSE: 13.0354 | Val MSE: 64.7125
# Epoch 94/250 | Train MSE: 12.3549 | Val MSE: 85.2141
# Epoch 95/250 | Train MSE: 12.8474 | Val MSE: 86.4818
# Epoch 96/250 | Train MSE: 12.9767 | Val MSE: 89.9444
# Epoch 97/250 | Train MSE: 12.5119 | Val MSE: 57.0094
# Epoch 98/250 | Train MSE: 12.0610 | Val MSE: 91.1649
# Epoch 99/250 | Train MSE: 12.2516 | Val MSE: 73.8349
# Epoch 100/250 | Train MSE: 12.4433 | Val MSE: 64.5652
# Epoch 101/250 | Train MSE: 11.9496 | Val MSE: 90.8904
# Epoch 102/250 | Train MSE: 12.4578 | Val MSE: 89.4928
# Epoch 103/250 | Train MSE: 13.1525 | Val MSE: 62.1566
# Epoch 104/250 | Train MSE: 13.1897 | Val MSE: 44.4562
# Epoch 105/250 | Train MSE: 12.6819 | Val MSE: 57.5466
# Epoch 106/250 | Train MSE: 12.2354 | Val MSE: 77.9862
# Epoch 107/250 | Train MSE: 11.9670 | Val MSE: 100.4220
# Epoch 108/250 | Train MSE: 12.7395 | Val MSE: 79.6004
# Epoch 109/250 | Train MSE: 11.9724 | Val MSE: 59.9989
# Epoch 110/250 | Train MSE: 12.7949 | Val MSE: 60.4158
# Epoch 111/250 | Train MSE: 11.9861 | Val MSE: 63.6118
# Epoch 112/250 | Train MSE: 12.7024 | Val MSE: 63.0262
# Epoch 113/250 | Train MSE: 12.1735 | Val MSE: 60.4036
# Epoch 114/250 | Train MSE: 11.7984 | Val MSE: 78.7147
# Epoch 115/250 | Train MSE: 12.2205 | Val MSE: 89.4316
# Epoch 116/250 | Train MSE: 12.4340 | Val MSE: 91.9894
# Epoch 117/250 | Train MSE: 11.6279 | Val MSE: 94.7816
# Epoch 118/250 | Train MSE: 11.7766 | Val MSE: 78.2425
# Epoch 119/250 | Train MSE: 12.1282 | Val MSE: 70.5492
# Epoch 120/250 | Train MSE: 11.7004 | Val MSE: 76.1804
# Epoch 121/250 | Train MSE: 12.2721 | Val MSE: 61.4006
# Epoch 122/250 | Train MSE: 12.5606 | Val MSE: 57.3202
# Epoch 123/250 | Train MSE: 12.2076 | Val MSE: 80.4093
# Epoch 124/250 | Train MSE: 12.3817 | Val MSE: 79.8665
# Epoch 125/250 | Train MSE: 12.4374 | Val MSE: 71.1399
# Epoch 126/250 | Train MSE: 12.6126 | Val MSE: 60.6394
# Epoch 127/250 | Train MSE: 11.9544 | Val MSE: 92.0120
# Epoch 128/250 | Train MSE: 11.5217 | Val MSE: 81.4245
# Epoch 129/250 | Train MSE: 12.1156 | Val MSE: 69.3541
# Epoch 130/250 | Train MSE: 11.6478 | Val MSE: 102.6812
# Epoch 131/250 | Train MSE: 11.7369 | Val MSE: 78.2621
# Epoch 132/250 | Train MSE: 12.0646 | Val MSE: 91.5794
# Epoch 133/250 | Train MSE: 11.5385 | Val MSE: 86.0486
# Epoch 134/250 | Train MSE: 11.4309 | Val MSE: 68.5905
# Epoch 135/250 | Train MSE: 11.7526 | Val MSE: 49.6448
# Epoch 136/250 | Train MSE: 11.6758 | Val MSE: 64.5969
# Epoch 137/250 | Train MSE: 11.4117 | Val MSE: 61.4104
# Epoch 138/250 | Train MSE: 11.4494 | Val MSE: 70.7613
# Epoch 139/250 | Train MSE: 11.9476 | Val MSE: 75.0648
# Epoch 140/250 | Train MSE: 12.9760 | Val MSE: 99.6622
# Epoch 141/250 | Train MSE: 11.5945 | Val MSE: 92.5736
# Epoch 142/250 | Train MSE: 11.3144 | Val MSE: 74.0549
# Epoch 143/250 | Train MSE: 11.9238 | Val MSE: 61.1903
# Epoch 144/250 | Train MSE: 11.9142 | Val MSE: 66.4089
# Epoch 145/250 | Train MSE: 11.4453 | Val MSE: 91.5837
# Epoch 146/250 | Train MSE: 11.7198 | Val MSE: 72.2245
# Epoch 147/250 | Train MSE: 10.8554 | Val MSE: 57.9363
# Epoch 148/250 | Train MSE: 11.9582 | Val MSE: 76.5918
# Epoch 149/250 | Train MSE: 12.1660 | Val MSE: 85.5449
# Epoch 150/250 | Train MSE: 11.4196 | Val MSE: 54.9396
# Epoch 151/250 | Train MSE: 11.4842 | Val MSE: 57.5875
# Epoch 152/250 | Train MSE: 11.8568 | Val MSE: 57.8558
# Epoch 153/250 | Train MSE: 11.2795 | Val MSE: 60.8459
# Epoch 154/250 | Train MSE: 11.3105 | Val MSE: 68.1680
# Epoch 155/250 | Train MSE: 11.8488 | Val MSE: 69.2031
# Epoch 156/250 | Train MSE: 11.5893 | Val MSE: 79.8354
# Epoch 157/250 | Train MSE: 11.2001 | Val MSE: 89.2254
# Epoch 158/250 | Train MSE: 11.1103 | Val MSE: 78.5567
# Epoch 159/250 | Train MSE: 11.0828 | Val MSE: 72.9671
# Epoch 160/250 | Train MSE: 11.3078 | Val MSE: 85.3816
# Epoch 161/250 | Train MSE: 11.4319 | Val MSE: 41.2103
# Epoch 162/250 | Train MSE: 11.3942 | Val MSE: 62.4792
# Epoch 163/250 | Train MSE: 11.4531 | Val MSE: 57.7853
# Epoch 164/250 | Train MSE: 11.3053 | Val MSE: 71.9080
# Epoch 165/250 | Train MSE: 11.4159 | Val MSE: 93.2011
# Epoch 166/250 | Train MSE: 11.4929 | Val MSE: 74.6962
# Epoch 167/250 | Train MSE: 11.0645 | Val MSE: 89.4659
# Epoch 168/250 | Train MSE: 11.2896 | Val MSE: 78.9777
# Epoch 169/250 | Train MSE: 11.4335 | Val MSE: 76.5915
# Epoch 170/250 | Train MSE: 11.2839 | Val MSE: 56.7593
# Epoch 171/250 | Train MSE: 11.2327 | Val MSE: 67.6542
# Epoch 172/250 | Train MSE: 11.3661 | Val MSE: 61.1150
# Epoch 173/250 | Train MSE: 11.1890 | Val MSE: 85.1490
# Epoch 174/250 | Train MSE: 11.2098 | Val MSE: 64.0345
# Epoch 175/250 | Train MSE: 11.4311 | Val MSE: 54.8274
# Epoch 176/250 | Train MSE: 10.9288 | Val MSE: 45.8206
# Epoch 177/250 | Train MSE: 11.3244 | Val MSE: 67.7938
# Epoch 178/250 | Train MSE: 11.2692 | Val MSE: 71.8119
# Epoch 179/250 | Train MSE: 11.1092 | Val MSE: 80.6646
# Epoch 180/250 | Train MSE: 11.0544 | Val MSE: 80.9319
# Epoch 181/250 | Train MSE: 11.0706 | Val MSE: 75.3382
# Epoch 182/250 | Train MSE: 10.6588 | Val MSE: 76.7163
# Epoch 183/250 | Train MSE: 10.8172 | Val MSE: 65.5935
# Epoch 184/250 | Train MSE: 11.3953 | Val MSE: 65.7889
# Epoch 185/250 | Train MSE: 10.9076 | Val MSE: 47.8860
# Epoch 186/250 | Train MSE: 11.7091 | Val MSE: 51.4325
# Epoch 187/250 | Train MSE: 11.6552 | Val MSE: 63.8724
# Epoch 188/250 | Train MSE: 10.8093 | Val MSE: 92.4424
# Epoch 189/250 | Train MSE: 11.0663 | Val MSE: 60.2622
# Epoch 190/250 | Train MSE: 11.7786 | Val MSE: 89.3131
# Epoch 191/250 | Train MSE: 11.5626 | Val MSE: 91.0874
# Epoch 192/250 | Train MSE: 10.5625 | Val MSE: 76.8837
# Epoch 193/250 | Train MSE: 10.7751 | Val MSE: 65.8117
# Epoch 194/250 | Train MSE: 11.0701 | Val MSE: 49.0843
# Epoch 195/250 | Train MSE: 10.9626 | Val MSE: 84.7861
# Epoch 196/250 | Train MSE: 10.5395 | Val MSE: 87.3175
# Epoch 197/250 | Train MSE: 10.8497 | Val MSE: 61.8588
# Epoch 198/250 | Train MSE: 11.0384 | Val MSE: 74.0729
# Epoch 199/250 | Train MSE: 10.8805 | Val MSE: 79.6495
# Epoch 200/250 | Train MSE: 11.2323 | Val MSE: 47.1260
# Epoch 201/250 | Train MSE: 10.9455 | Val MSE: 79.6859
# Epoch 202/250 | Train MSE: 10.5838 | Val MSE: 68.3328
# Epoch 203/250 | Train MSE: 10.9418 | Val MSE: 86.2773
# Epoch 204/250 | Train MSE: 10.9450 | Val MSE: 65.9691
# Epoch 205/250 | Train MSE: 10.7696 | Val MSE: 78.4740
# Epoch 206/250 | Train MSE: 11.0409 | Val MSE: 85.9558
# Epoch 207/250 | Train MSE: 11.3672 | Val MSE: 100.5033
# Epoch 208/250 | Train MSE: 10.9657 | Val MSE: 68.9292
# Epoch 209/250 | Train MSE: 10.8188 | Val MSE: 77.1491
# Epoch 210/250 | Train MSE: 10.8878 | Val MSE: 51.1489
# Epoch 211/250 | Train MSE: 10.6415 | Val MSE: 52.1730
# Epoch 212/250 | Train MSE: 10.6598 | Val MSE: 86.0473
# Epoch 213/250 | Train MSE: 10.3097 | Val MSE: 76.3325
# Epoch 214/250 | Train MSE: 10.4468 | Val MSE: 88.3018
# Epoch 215/250 | Train MSE: 10.6202 | Val MSE: 78.4620
# Epoch 216/250 | Train MSE: 11.4411 | Val MSE: 101.1547
# Epoch 217/250 | Train MSE: 11.3446 | Val MSE: 93.5307
# Epoch 218/250 | Train MSE: 10.8094 | Val MSE: 104.6798
# Epoch 219/250 | Train MSE: 10.4959 | Val MSE: 76.3422
# Epoch 220/250 | Train MSE: 10.7698 | Val MSE: 93.3202
# Epoch 221/250 | Train MSE: 10.4055 | Val MSE: 94.0225
# Epoch 222/250 | Train MSE: 10.5918 | Val MSE: 67.4941
# Epoch 223/250 | Train MSE: 10.4465 | Val MSE: 68.3940
# Epoch 224/250 | Train MSE: 10.5786 | Val MSE: 78.5208
# Epoch 225/250 | Train MSE: 11.1162 | Val MSE: 55.6513
# Epoch 226/250 | Train MSE: 10.7182 | Val MSE: 60.0546
# Epoch 227/250 | Train MSE: 10.4698 | Val MSE: 70.7477
# Epoch 228/250 | Train MSE: 10.4691 | Val MSE: 69.2164
# Epoch 229/250 | Train MSE: 10.5676 | Val MSE: 65.8465
# Epoch 230/250 | Train MSE: 10.3549 | Val MSE: 77.6024
# Epoch 231/250 | Train MSE: 10.7460 | Val MSE: 62.4350
# Epoch 232/250 | Train MSE: 10.3393 | Val MSE: 100.6526
# Epoch 233/250 | Train MSE: 10.6345 | Val MSE: 80.0908
# Epoch 234/250 | Train MSE: 10.3152 | Val MSE: 103.9403
# Epoch 235/250 | Train MSE: 10.5375 | Val MSE: 54.2863
# Epoch 236/250 | Train MSE: 10.7952 | Val MSE: 84.0996
# Epoch 237/250 | Train MSE: 10.3339 | Val MSE: 90.7220
# Epoch 238/250 | Train MSE: 10.3047 | Val MSE: 82.1531
# Epoch 239/250 | Train MSE: 10.8069 | Val MSE: 68.7512
# Epoch 240/250 | Train MSE: 10.2044 | Val MSE: 96.2289
# Epoch 241/250 | Train MSE: 10.5092 | Val MSE: 70.6184
# Epoch 242/250 | Train MSE: 10.3753 | Val MSE: 107.7499
# Epoch 243/250 | Train MSE: 10.8712 | Val MSE: 64.1673
# Epoch 244/250 | Train MSE: 10.6156 | Val MSE: 98.1692
# Epoch 245/250 | Train MSE: 10.4637 | Val MSE: 68.0040
# Epoch 246/250 | Train MSE: 10.2696 | Val MSE: 64.9505
# Epoch 247/250 | Train MSE: 10.4277 | Val MSE: 90.9696
# Epoch 248/250 | Train MSE: 10.8387 | Val MSE: 79.1082
# Epoch 249/250 | Train MSE: 10.3119 | Val MSE: 50.1985
# Epoch 250/250 | Train MSE: 10.1067 | Val MSE: 57.1582
# Test MSE: 45.6435
